# %% [markdown]
# # **🤖Reinforcement Learning in Control: HW4**

# %% [markdown]
# ## Part 1️⃣: Monte Carlo Methods

# %% [markdown]
# ![what-is-a-slot-machine.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ### 🟩 Step 1: Install Minigrid

# %%
# install gymnasium here
# !pip install -q swig
# !pip install -q "gymnasium[all]"
# !python3 -m pip install minigrid
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 22.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 5.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 48.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 56.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.5/243.5 kB 19.0 MB/s eta 0:00:00
#   Building wheel for box2d-py (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
# Requirement already satisfied: minigrid in /usr/local/lib/python3.12/dist-packages (3.0.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.12/dist-packages (from minigrid) (2.2.6)
# Requirement already satisfied: gymnasium>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from minigrid) (1.2.1)
# Requirement already satisfied: pygame>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from minigrid) (2.6.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium>=0.28.1->minigrid) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium>=0.28.1->minigrid) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium>=0.28.1->minigrid) (0.0.4)

# %% [markdown]
# You have to install some other dependencies for visualizing the environment. Check this [link](https://stackoverflow.com/questions/50107530/how-to-render-openai-gym-in-google-colab).

# %%
# !pip install -q moviepy

# %%
# disable warnings
import warnings
warnings.filterwarnings("ignore")

# define visualizer function
from moviepy.editor import ImageSequenceClip
from IPython.display import HTML
from base64 import b64encode

def show_video_from_frames(frames, filename="all_episodes.mp4", fps=30, height=400):
    """
    Create and display a single video from a list of frames in Colab.

    Args:
        frames: List of frames (numpy arrays) obtained from env.render(mode='rgb_array')
        filename: Name of the output video file
        fps: Frames per second of the video
        height: Display height of the video in Colab
    """
    # Create video from frames
    clip = ImageSequenceClip(frames, fps=fps)
    clip.write_videofile(filename, verbose=False, logger=None)  # suppress extra logs

    # Read video and convert to Base64 for display in Colab
    mp4 = open(filename, "rb").read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

    # Display video
    return HTML(f'<video controls autoplay loop src="{data_url}" style="height:{height}px;"></video>')

# %% [markdown]
# ### 🟩 Step 2: Implement On Policy Monte Carlo on Dist Shift Environment

# %%
# TODO: your code here

# %%
# TODO: visualize the Performance of trained agent on environment

# %% [markdown]
# ### 🟩 Step 3: Implement Off Policy Monte Carlo on Dist Shift Environment

# %%
# TODO: your code here

# %%
# TODO: visualize the Performance of trained agent on environment
